# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 590

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bilibino
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | port lincoln
# Processing Record 4 of Set 1 | olonkinbyen
# Processing Record 5 of Set 1 | invercargill
# Processing Record 6 of Set 1 | arnprior
# Processing Record 7 of Set 1 | geraldton
# Processing Record 8 of Set 1 | puerto natales
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | nemuro
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | carauari
# Processing Record 13 of Set 1 | mahmudabad
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | kijang
# Processing Record 16 of Set 1 | dhidhdhoo
# Processing Record 17 of Set 1 | wailua homesteads
# Processing Record 18 of Set 1 | ladismith
# City not found. Skipping...
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | campo formoso
# Processing Record 21 of Set 1 | ujae
# Processing Record 22 of Set 1 | grytviken
# Processing Record 23 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 24 of Set 1 | port hedland
# Processing Record 25 of Set 1 | san patricio
# Processing Record 26 of Set 1 | aykhal
# Processing Record 27 of Set 1 | isafjordur
# Processing Record 28 of Set 1 | kourou
# Processing Record 29 of Set 1 | auki
# Processing Record 30 of Set 1 | ngetkib
# Processing Record 31 of Set 1 | montelibano
# Processing Record 32 of Set 1 | ugoofaaru
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | vorgashor
# Processing Record 35 of Set 1 | chonchi
# Processing Record 36 of Set 1 | blackmans bay
# Processing Record 37 of Set 1 | talnakh
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | retreat
# Processing Record 40 of Set 1 | carahue
# Processing Record 41 of Set 1 | whitehorse
# Processing Record 42 of Set 1 | enewetak
# Processing Record 43 of Set 1 | hayma'
# City not found. Skipping...
# Processing Record 44 of Set 1 | karratha
# Processing Record 45 of Set 1 | klyuchi
# Processing Record 46 of Set 1 | constitucion
# Processing Record 47 of Set 1 | kingscliff
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | adamstown
# Processing Record 0 of Set 2 | constantia
# Processing Record 1 of Set 2 | guerrero negro
# Processing Record 2 of Set 2 | batang
# Processing Record 3 of Set 2 | sitka
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | pimentel
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | jaffna
# Processing Record 8 of Set 2 | port blair
# Processing Record 9 of Set 2 | papatowai
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 2 | mosjoen
# Processing Record 13 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 14 of Set 2 | edinburgh of the seven seas
# Processing Record 15 of Set 2 | sealy
# Processing Record 16 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | utrik
# Processing Record 19 of Set 2 | port mathurin
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | kuala terengganu
# Processing Record 22 of Set 2 | happy valley-goose bay
# Processing Record 23 of Set 2 | long beach
# Processing Record 24 of Set 2 | cadale
# Processing Record 25 of Set 2 | gadzhiyevo
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | cheyyur
# Processing Record 28 of Set 2 | st. john's
# Processing Record 29 of Set 2 | aykol
# City not found. Skipping...
# Processing Record 30 of Set 2 | fort mcmurray
# Processing Record 31 of Set 2 | ishigaki
# Processing Record 32 of Set 2 | veraval
# Processing Record 33 of Set 2 | mamontovo
# Processing Record 34 of Set 2 | iskateley
# Processing Record 35 of Set 2 | wenchang
# Processing Record 36 of Set 2 | polyarnyy
# Processing Record 37 of Set 2 | tuensang
# Processing Record 38 of Set 2 | mejit
# Processing Record 39 of Set 2 | margaret river
# Processing Record 40 of Set 2 | codrington
# Processing Record 41 of Set 2 | cockburn town
# Processing Record 42 of Set 2 | nueva gerona
# Processing Record 43 of Set 2 | sur
# Processing Record 44 of Set 2 | saint-philippe
# Processing Record 45 of Set 2 | ca mau
# Processing Record 46 of Set 2 | puerto lleras
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | broken hill
# Processing Record 49 of Set 2 | atafu village
# Processing Record 0 of Set 3 | prince rupert
# Processing Record 1 of Set 3 | vernon
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | esil
# Processing Record 4 of Set 3 | sisimiut
# Processing Record 5 of Set 3 | moyale
# Processing Record 6 of Set 3 | qaqortoq
# Processing Record 7 of Set 3 | rio grande
# Processing Record 8 of Set 3 | stanley
# Processing Record 9 of Set 3 | salaqi
# Processing Record 10 of Set 3 | el bauga
# Processing Record 11 of Set 3 | ketchikan
# Processing Record 12 of Set 3 | hawaiian paradise park
# Processing Record 13 of Set 3 | iqaluit
# Processing Record 14 of Set 3 | ivins
# Processing Record 15 of Set 3 | flying fish cove
# Processing Record 16 of Set 3 | grand falls-windsor
# Processing Record 17 of Set 3 | hachinohe
# Processing Record 18 of Set 3 | west island
# Processing Record 19 of Set 3 | abadeh
# Processing Record 20 of Set 3 | puerto ayora
# Processing Record 21 of Set 3 | nikel
# Processing Record 22 of Set 3 | cole harbour
# Processing Record 23 of Set 3 | nouadhibou
# Processing Record 24 of Set 3 | hwange
# Processing Record 25 of Set 3 | la passe
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | chishmy
# Processing Record 28 of Set 3 | nar'yan-mar
# Processing Record 29 of Set 3 | ancud
# Processing Record 30 of Set 3 | bubaque
# Processing Record 31 of Set 3 | timbuktu
# Processing Record 32 of Set 3 | altai
# Processing Record 33 of Set 3 | badger
# Processing Record 34 of Set 3 | bandarbeyla
# Processing Record 35 of Set 3 | manvi
# Processing Record 36 of Set 3 | arraial do cabo
# Processing Record 37 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 38 of Set 3 | el fasher
# Processing Record 39 of Set 3 | belmonte
# Processing Record 40 of Set 3 | udachny
# Processing Record 41 of Set 3 | college
# Processing Record 42 of Set 3 | san luis de la loma
# Processing Record 43 of Set 3 | lyozna
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | tabuk
# Processing Record 46 of Set 3 | brisas barra de suchiate
# Processing Record 47 of Set 3 | haiku-pauwela
# Processing Record 48 of Set 3 | gordonvale
# Processing Record 49 of Set 3 | uyovu
# Processing Record 0 of Set 4 | ust-nera
# Processing Record 1 of Set 4 | vila franca do campo
# Processing Record 2 of Set 4 | pemangkat
# Processing Record 3 of Set 4 | luganville
# Processing Record 4 of Set 4 | pauini
# Processing Record 5 of Set 4 | dalnegorsk
# Processing Record 6 of Set 4 | san jose village
# City not found. Skipping...
# Processing Record 7 of Set 4 | vung tau
# Processing Record 8 of Set 4 | vilyuysk
# Processing Record 9 of Set 4 | remire-montjoly
# Processing Record 10 of Set 4 | gizo
# Processing Record 11 of Set 4 | olyokminsk
# Processing Record 12 of Set 4 | lagunas
# Processing Record 13 of Set 4 | al hoceima
# Processing Record 14 of Set 4 | tra vinh
# Processing Record 15 of Set 4 | muravlenko
# Processing Record 16 of Set 4 | maragogi
# Processing Record 17 of Set 4 | lusambo
# Processing Record 18 of Set 4 | kavaratti
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | sinabang
# Processing Record 21 of Set 4 | poronaysk
# Processing Record 22 of Set 4 | anadyr
# Processing Record 23 of Set 4 | zaozersk
# Processing Record 24 of Set 4 | tambura
# Processing Record 25 of Set 4 | prado
# Processing Record 26 of Set 4 | island harbour
# Processing Record 27 of Set 4 | yuzhno-kurilsk
# Processing Record 28 of Set 4 | kodiak
# Processing Record 29 of Set 4 | pisco
# Processing Record 30 of Set 4 | vilyuchinsk
# Processing Record 31 of Set 4 | khandyga
# Processing Record 32 of Set 4 | zeya
# Processing Record 33 of Set 4 | algona
# Processing Record 34 of Set 4 | enriquillo
# Processing Record 35 of Set 4 | kristiansund
# Processing Record 36 of Set 4 | yamba
# Processing Record 37 of Set 4 | bang pakong
# Processing Record 38 of Set 4 | buka
# Processing Record 39 of Set 4 | kamina
# Processing Record 40 of Set 4 | itaueira
# Processing Record 41 of Set 4 | mermoz boabab
# Processing Record 42 of Set 4 | hasaki
# Processing Record 43 of Set 4 | jiwani
# Processing Record 44 of Set 4 | achinsk
# Processing Record 45 of Set 4 | bafq
# Processing Record 46 of Set 4 | cidreira
# Processing Record 47 of Set 4 | thunder bay
# Processing Record 48 of Set 4 | kulhudhuffushi
# Processing Record 49 of Set 4 | luwuk
# Processing Record 0 of Set 5 | peniche
# Processing Record 1 of Set 5 | chibougamau
# Processing Record 2 of Set 5 | antsiranana
# Processing Record 3 of Set 5 | saint-pierre
# Processing Record 4 of Set 5 | ubari
# Processing Record 5 of Set 5 | slave lake
# Processing Record 6 of Set 5 | fang
# Processing Record 7 of Set 5 | kiama
# Processing Record 8 of Set 5 | alofi
# Processing Record 9 of Set 5 | xilin hot
# Processing Record 10 of Set 5 | turinsk
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | kentau
# Processing Record 13 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 5 | fortuna
# Processing Record 15 of Set 5 | punta arenas
# Processing Record 16 of Set 5 | fort st. john
# Processing Record 17 of Set 5 | riosucio
# Processing Record 18 of Set 5 | aldama
# Processing Record 19 of Set 5 | nuuk
# Processing Record 20 of Set 5 | avarua
# Processing Record 21 of Set 5 | lazaro cardenas
# Processing Record 22 of Set 5 | labuan
# Processing Record 23 of Set 5 | acapulco de juarez
# Processing Record 24 of Set 5 | abepura
# Processing Record 25 of Set 5 | kaa-khem
# Processing Record 26 of Set 5 | ylitornio
# Processing Record 27 of Set 5 | humaita
# Processing Record 28 of Set 5 | tura
# Processing Record 29 of Set 5 | porto velho
# Processing Record 30 of Set 5 | fort bragg
# Processing Record 31 of Set 5 | novohrad-volynskyi
# Processing Record 32 of Set 5 | alice springs
# Processing Record 33 of Set 5 | villa huidobro
# Processing Record 34 of Set 5 | tralee
# Processing Record 35 of Set 5 | suva
# Processing Record 36 of Set 5 | newman
# Processing Record 37 of Set 5 | 'ibri
# City not found. Skipping...
# Processing Record 38 of Set 5 | khanty-mansiysk
# Processing Record 39 of Set 5 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 40 of Set 5 | gemena
# Processing Record 41 of Set 5 | novodvinsk
# Processing Record 42 of Set 5 | yeosu
# Processing Record 43 of Set 5 | uturoa
# Processing Record 44 of Set 5 | kencong
# Processing Record 45 of Set 5 | coxen hole
# Processing Record 46 of Set 5 | yanchep
# Processing Record 47 of Set 5 | tual
# Processing Record 48 of Set 5 | tamiahua
# Processing Record 49 of Set 5 | ribeira grande
# Processing Record 0 of Set 6 | kharp
# Processing Record 1 of Set 6 | koryazhma
# Processing Record 2 of Set 6 | oamaru
# Processing Record 3 of Set 6 | cabo san lucas
# Processing Record 4 of Set 6 | yaring
# Processing Record 5 of Set 6 | antofagasta
# Processing Record 6 of Set 6 | lorengau
# Processing Record 7 of Set 6 | mahuta
# Processing Record 8 of Set 6 | minas de marcona
# Processing Record 9 of Set 6 | howrah
# Processing Record 10 of Set 6 | dryden
# Processing Record 11 of Set 6 | papao
# Processing Record 12 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 13 of Set 6 | portage la prairie
# Processing Record 14 of Set 6 | san julian
# Processing Record 15 of Set 6 | matanzas
# Processing Record 16 of Set 6 | belo sur tsiribihina
# Processing Record 17 of Set 6 | baiyin
# Processing Record 18 of Set 6 | santo antonio do ica
# Processing Record 19 of Set 6 | la'ie
# Processing Record 20 of Set 6 | swakopmund
# Processing Record 21 of Set 6 | chabahar
# Processing Record 22 of Set 6 | alaghsas
# Processing Record 23 of Set 6 | sungai raya
# Processing Record 24 of Set 6 | taghazout
# Processing Record 25 of Set 6 | bull savanna
# Processing Record 26 of Set 6 | xiva
# Processing Record 27 of Set 6 | francistown
# Processing Record 28 of Set 6 | portland
# Processing Record 29 of Set 6 | plan de ayala
# Processing Record 30 of Set 6 | soio
# Processing Record 31 of Set 6 | tanrake village
# City not found. Skipping...
# Processing Record 32 of Set 6 | zapolyarnyy
# Processing Record 33 of Set 6 | callao
# Processing Record 34 of Set 6 | tofol
# Processing Record 35 of Set 6 | kayangel
# Processing Record 36 of Set 6 | butner
# Processing Record 37 of Set 6 | pangoa
# Processing Record 38 of Set 6 | colonia
# Processing Record 39 of Set 6 | bitburg
# Processing Record 40 of Set 6 | howard springs
# Processing Record 41 of Set 6 | kavieng
# Processing Record 42 of Set 6 | byron bay
# Processing Record 43 of Set 6 | usinsk
# Processing Record 44 of Set 6 | vorkuta
# Processing Record 45 of Set 6 | phan rang-thap cham
# Processing Record 46 of Set 6 | oujda-angad
# Processing Record 47 of Set 6 | banda aceh
# Processing Record 48 of Set 6 | otaru
# Processing Record 49 of Set 6 | ghat
# Processing Record 0 of Set 7 | dingras
# Processing Record 1 of Set 7 | formosa
# Processing Record 2 of Set 7 | coquimbo
# Processing Record 3 of Set 7 | heber springs
# Processing Record 4 of Set 7 | orichi
# Processing Record 5 of Set 7 | navirai
# Processing Record 6 of Set 7 | tobi village
# City not found. Skipping...
# Processing Record 7 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 8 of Set 7 | kingston
# Processing Record 9 of Set 7 | corner brook
# Processing Record 10 of Set 7 | lompoc
# Processing Record 11 of Set 7 | estevan
# Processing Record 12 of Set 7 | dudinka
# Processing Record 13 of Set 7 | romitan shahri
# City not found. Skipping...
# Processing Record 14 of Set 7 | garoowe
# Processing Record 15 of Set 7 | murghob
# Processing Record 16 of Set 7 | jayapura
# Processing Record 17 of Set 7 | gubkinskiy
# Processing Record 18 of Set 7 | neiafu
# Processing Record 19 of Set 7 | port augusta
# Processing Record 20 of Set 7 | severinia
# Processing Record 21 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 22 of Set 7 | belidzhi
# Processing Record 23 of Set 7 | nacala
# Processing Record 24 of Set 7 | aasiaat
# Processing Record 25 of Set 7 | booue
# Processing Record 26 of Set 7 | dietenhofen
# Processing Record 27 of Set 7 | grunheide
# Processing Record 28 of Set 7 | fale old settlement
# Processing Record 29 of Set 7 | shache
# Processing Record 30 of Set 7 | dunedin
# Processing Record 31 of Set 7 | wawarsing
# Processing Record 32 of Set 7 | arar
# Processing Record 33 of Set 7 | tolanaro
# Processing Record 34 of Set 7 | kone
# Processing Record 35 of Set 7 | new norfolk
# Processing Record 36 of Set 7 | dauphin
# Processing Record 37 of Set 7 | lobujya
# Processing Record 38 of Set 7 | mount pearl
# Processing Record 39 of Set 7 | virginia beach
# Processing Record 40 of Set 7 | hadibu
# Processing Record 41 of Set 7 | otacilio costa
# Processing Record 42 of Set 7 | valparaiso
# Processing Record 43 of Set 7 | mega
# Processing Record 44 of Set 7 | santa cecilia
# Processing Record 45 of Set 7 | tapes
# Processing Record 46 of Set 7 | naliya
# Processing Record 47 of Set 7 | tafuna
# Processing Record 48 of Set 7 | aioun
# Processing Record 49 of Set 7 | puerto deseado
# Processing Record 0 of Set 8 | basco
# Processing Record 1 of Set 8 | cambria
# Processing Record 2 of Set 8 | bakchar
# Processing Record 3 of Set 8 | yarkovo
# Processing Record 4 of Set 8 | ust-tsilma
# Processing Record 5 of Set 8 | cold springs
# Processing Record 6 of Set 8 | guarapari
# Processing Record 7 of Set 8 | egersund
# Processing Record 8 of Set 8 | nuku'alofa
# Processing Record 9 of Set 8 | filipstad
# Processing Record 10 of Set 8 | acarau
# Processing Record 11 of Set 8 | porto novo
# Processing Record 12 of Set 8 | amatitan
# Processing Record 13 of Set 8 | al karamah
# Processing Record 14 of Set 8 | vakarai
# Processing Record 15 of Set 8 | eraan
# Processing Record 16 of Set 8 | manismata
# Processing Record 17 of Set 8 | nagqu
# Processing Record 18 of Set 8 | afaahiti
# Processing Record 19 of Set 8 | ankang
# Processing Record 20 of Set 8 | crane
# Processing Record 21 of Set 8 | kulia village
# City not found. Skipping...
# Processing Record 22 of Set 8 | undurkhaan
# Processing Record 23 of Set 8 | earlimart
# Processing Record 24 of Set 8 | namibe
# Processing Record 25 of Set 8 | gisborne
# Processing Record 26 of Set 8 | jonava
# Processing Record 27 of Set 8 | ad dawadimi
# Processing Record 28 of Set 8 | san sebastian de la gomera
# Processing Record 29 of Set 8 | soufriere
# Processing Record 30 of Set 8 | argo
# Processing Record 31 of Set 8 | champerico
# Processing Record 32 of Set 8 | tarauaca
# Processing Record 33 of Set 8 | skeldon
# Processing Record 34 of Set 8 | kilindoni
# Processing Record 35 of Set 8 | krumovgrad
# Processing Record 36 of Set 8 | keflavik
# Processing Record 37 of Set 8 | labytnangi
# Processing Record 38 of Set 8 | namie
# Processing Record 39 of Set 8 | kailua-kona
# Processing Record 40 of Set 8 | pedernales
# Processing Record 41 of Set 8 | arkhangel'sk
# Processing Record 42 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 43 of Set 8 | beira
# Processing Record 44 of Set 8 | kruisfontein
# Processing Record 45 of Set 8 | varallo
# Processing Record 46 of Set 8 | bikenibeu village
# Processing Record 47 of Set 8 | saratamata
# City not found. Skipping...
# Processing Record 48 of Set 8 | sofo-birnin-gwari
# Processing Record 49 of Set 8 | sao gabriel da cachoeira
# Processing Record 0 of Set 9 | yemel'yanovo
# Processing Record 1 of Set 9 | lerwick
# Processing Record 2 of Set 9 | cable beach
# City not found. Skipping...
# Processing Record 3 of Set 9 | alliance
# Processing Record 4 of Set 9 | salekhard
# Processing Record 5 of Set 9 | maua
# Processing Record 6 of Set 9 | saipan
# Processing Record 7 of Set 9 | nicoya
# Processing Record 8 of Set 9 | kerikeri
# Processing Record 9 of Set 9 | kismayo
# Processing Record 10 of Set 9 | bovalino superiore
# Processing Record 11 of Set 9 | patnanungan
# Processing Record 12 of Set 9 | charters towers
# Processing Record 13 of Set 9 | pernio
# Processing Record 14 of Set 9 | hohhot
# Processing Record 15 of Set 9 | okoneshnikovo
# Processing Record 16 of Set 9 | puerto baquerizo moreno
# Processing Record 17 of Set 9 | rukban
# City not found. Skipping...
# Processing Record 18 of Set 9 | albania
# Processing Record 19 of Set 9 | pasargad
# City not found. Skipping...
# Processing Record 20 of Set 9 | taoudenni
# Processing Record 21 of Set 9 | cooper's town
# Processing Record 22 of Set 9 | mont-dore
# Processing Record 23 of Set 9 | alcantara
# Processing Record 24 of Set 9 | tapa
# Processing Record 25 of Set 9 | pacific grove
# Processing Record 26 of Set 9 | kolonia
# Processing Record 27 of Set 9 | carutapera
# Processing Record 28 of Set 9 | tamanrasset
# Processing Record 29 of Set 9 | cururupu
# Processing Record 30 of Set 9 | chernyshevskiy
# Processing Record 31 of Set 9 | palmer
# Processing Record 32 of Set 9 | gaalkacyo
# Processing Record 33 of Set 9 | tomatlan
# Processing Record 34 of Set 9 | saint-joseph
# Processing Record 35 of Set 9 | mount hagen
# Processing Record 36 of Set 9 | susuman
# Processing Record 37 of Set 9 | berdigestyakh
# Processing Record 38 of Set 9 | hovd
# Processing Record 39 of Set 9 | viedma
# Processing Record 40 of Set 9 | junin
# Processing Record 41 of Set 9 | dom pedro
# Processing Record 42 of Set 9 | lihue
# Processing Record 43 of Set 9 | mantua
# Processing Record 44 of Set 9 | colby
# Processing Record 45 of Set 9 | pathein
# Processing Record 46 of Set 9 | kapuskasing
# Processing Record 47 of Set 9 | herval
# Processing Record 48 of Set 9 | podporozh'ye
# Processing Record 49 of Set 9 | preobrazheniye
# Processing Record 0 of Set 10 | pasni
# Processing Record 1 of Set 10 | paradip garh
# Processing Record 2 of Set 10 | rawson
# Processing Record 3 of Set 10 | muleshoe
# Processing Record 4 of Set 10 | mahdia
# Processing Record 5 of Set 10 | ed damer
# Processing Record 6 of Set 10 | veymandoo
# City not found. Skipping...
# Processing Record 7 of Set 10 | yeppoon
# Processing Record 8 of Set 10 | nadur
# Processing Record 9 of Set 10 | ridgecrest
# Processing Record 10 of Set 10 | san antonio de pale
# Processing Record 11 of Set 10 | zhezqazghan
# Processing Record 12 of Set 10 | port alfred
# Processing Record 13 of Set 10 | nobeoka
# Processing Record 14 of Set 10 | marandahalli
# Processing Record 15 of Set 10 | isangel
# Processing Record 16 of Set 10 | cristalina
# Processing Record 17 of Set 10 | zhirnovsk
# Processing Record 18 of Set 10 | jiayuguan
# Processing Record 19 of Set 10 | ko pha ngan
# Processing Record 20 of Set 10 | mazagao
# Processing Record 21 of Set 10 | praia da vitoria
# Processing Record 22 of Set 10 | kattivakkam
# Processing Record 23 of Set 10 | chany
# Processing Record 24 of Set 10 | vadso
# Processing Record 25 of Set 10 | dayr hafir
# Processing Record 26 of Set 10 | rundu
# Processing Record 27 of Set 10 | chimoio
# Processing Record 28 of Set 10 | alappuzha
# Processing Record 29 of Set 10 | pulandian
# Processing Record 30 of Set 10 | tsiombe
# Processing Record 31 of Set 10 | andippatti
# Processing Record 32 of Set 10 | laojunmiao
# Processing Record 33 of Set 10 | itoman
# Processing Record 34 of Set 10 | aketi
# Processing Record 35 of Set 10 | nahiyat ash shinafiyah
# Processing Record 36 of Set 10 | elko
# Processing Record 37 of Set 10 | daru
# Processing Record 38 of Set 10 | suntar
# Processing Record 39 of Set 10 | macapa
# Processing Record 40 of Set 10 | galveston
# Processing Record 41 of Set 10 | madalena
# Processing Record 42 of Set 10 | zahedan
# Processing Record 43 of Set 10 | panaba
# Processing Record 44 of Set 10 | vila velha
# Processing Record 45 of Set 10 | akureyri
# Processing Record 46 of Set 10 | illela
# Processing Record 47 of Set 10 | manokwari
# Processing Record 48 of Set 10 | bayramaly
# Processing Record 49 of Set 10 | lijiang
# Processing Record 0 of Set 11 | nhamunda
# Processing Record 1 of Set 11 | dakhla
# Processing Record 2 of Set 11 | nelson bay
# Processing Record 3 of Set 11 | asifabad
# Processing Record 4 of Set 11 | tazovsky
# Processing Record 5 of Set 11 | great falls
# Processing Record 6 of Set 11 | bantay
# Processing Record 7 of Set 11 | kadugli
# Processing Record 8 of Set 11 | northport
# Processing Record 9 of Set 11 | north bend
# Processing Record 10 of Set 11 | santa rosalia
# Processing Record 11 of Set 11 | goundam
# Processing Record 12 of Set 11 | thinadhoo
# Processing Record 13 of Set 11 | oualidia
# City not found. Skipping...
# Processing Record 14 of Set 11 | tangalle
# Processing Record 15 of Set 11 | la ligua
# Processing Record 16 of Set 11 | richards bay
# Processing Record 17 of Set 11 | paita
# Processing Record 18 of Set 11 | ulladulla
# Processing Record 19 of Set 11 | trunovskoye
# Processing Record 20 of Set 11 | bac lieu
# Processing Record 21 of Set 11 | quatre cocos
# Processing Record 22 of Set 11 | port-vila
# Processing Record 23 of Set 11 | tonghae
# Processing Record 24 of Set 11 | inekar
# City not found. Skipping...
# Processing Record 25 of Set 11 | floro
# Processing Record 26 of Set 11 | isle of lewis
# City not found. Skipping...
# Processing Record 27 of Set 11 | namikupa
# Processing Record 28 of Set 11 | tasqala
# Processing Record 29 of Set 11 | addanki
# Processing Record 30 of Set 11 | kataragama
# City not found. Skipping...
# Processing Record 31 of Set 11 | castillos
# Processing Record 32 of Set 11 | natal
# Processing Record 33 of Set 11 | bodaybo
# Processing Record 34 of Set 11 | kangding
# Processing Record 35 of Set 11 | roosevelt
# Processing Record 36 of Set 11 | aracataca
# Processing Record 37 of Set 11 | shira
# Processing Record 38 of Set 11 | bratsk
# Processing Record 39 of Set 11 | berezovyy
# Processing Record 40 of Set 11 | arkansas city
# Processing Record 41 of Set 11 | aso
# Processing Record 42 of Set 11 | balykshi
# Processing Record 43 of Set 11 | kenai
# Processing Record 44 of Set 11 | kaiapoi
# Processing Record 45 of Set 11 | bairnsdale
# Processing Record 46 of Set 11 | ataq
# Processing Record 47 of Set 11 | hafar al-batin
# Processing Record 48 of Set 11 | mahanoro
# Processing Record 49 of Set 11 | moa
# Processing Record 0 of Set 12 | caleta de carquin
# Processing Record 1 of Set 12 | vanimo
# Processing Record 2 of Set 12 | simanggang
# Processing Record 3 of Set 12 | bacolod
# Processing Record 4 of Set 12 | puerto la cruz
# Processing Record 5 of Set 12 | nguekhokh
# Processing Record 6 of Set 12 | fisterra
# Processing Record 7 of Set 12 | ahfir
# Processing Record 8 of Set 12 | woolgoolga
# Processing Record 9 of Set 12 | alta
# Processing Record 10 of Set 12 | okeho
# Processing Record 11 of Set 12 | manado
# Processing Record 12 of Set 12 | salinopolis
# Processing Record 13 of Set 12 | el abiodh sidi cheikh
# Processing Record 14 of Set 12 | nyurba
# Processing Record 15 of Set 12 | calca
# Processing Record 16 of Set 12 | turbat
# Processing Record 17 of Set 12 | huinan
# Processing Record 18 of Set 12 | marijampole
# Processing Record 19 of Set 12 | katsuura
# Processing Record 20 of Set 12 | crozon
# Processing Record 21 of Set 12 | sept-iles
# Processing Record 22 of Set 12 | kalaleh
# Processing Record 23 of Set 12 | mwinilunga
# Processing Record 24 of Set 12 | naze
# Processing Record 25 of Set 12 | nova sintra
# Processing Record 26 of Set 12 | santa cruz
# Processing Record 27 of Set 12 | konstantinovka
# Processing Record 28 of Set 12 | mata-utu
# Processing Record 29 of Set 12 | bengkulu
# Processing Record 30 of Set 12 | ciudad lazaro cardenas
# Processing Record 31 of Set 12 | pangody
# Processing Record 32 of Set 12 | devinuwara
# City not found. Skipping...
# Processing Record 33 of Set 12 | severo-yeniseyskiy
# Processing Record 34 of Set 12 | tubas
# Processing Record 35 of Set 12 | malanje
# Processing Record 36 of Set 12 | piti village
# Processing Record 37 of Set 12 | pariaman
# Processing Record 38 of Set 12 | lata
# Processing Record 39 of Set 12 | maumere
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      bilibino  68.0546  166.4372     16.49        37           8
# 1        albany  42.6001  -73.9662     18.21        68          89
# 2  port lincoln -34.7333  135.8667     13.67        57         100
# 3   olonkinbyen  70.9221   -8.7187      2.34        97         100
# 4  invercargill -46.4000  168.3500      2.51        89           8
#
#    Wind Speed Country        Date
# 0        1.07      RU  1686261475
# 1        1.99      US  1686261442
# 2        6.23      AU  1686261475
# 3        8.51      SJ  1686261475
# 4        1.57      NZ  1686261042

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            bilibino  68.0546  166.4372     16.49        37           8
# 1              albany  42.6001  -73.9662     18.21        68          89
# 2        port lincoln -34.7333  135.8667     13.67        57         100
# 3         olonkinbyen  70.9221   -8.7187      2.34        97         100
# 4        invercargill -46.4000  168.3500      2.51        89           8
#
#          Wind Speed Country        Date
# City_ID
# 0              1.07      RU  1686261475
# 1              1.99      US  1686261442
# 2              6.23      AU  1686261475
# 3              8.51      SJ  1686261475
# 4              1.57      NZ  1686261042

# %%
#Remove null values
city_data_df = city_data_df.dropna()
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 558 entries, 0 to 560
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        558 non-null    object
#  1   Lat         558 non-null    float64
#  2   Lng         558 non-null    float64
#  3   Max Temp    558 non-null    float64
#  4   Humidity    558 non-null    int64
#  5   Cloudiness  558 non-null    int64
#  6   Wind Speed  558 non-null    float64
#  7   Country     558 non-null    object
#  8   Date        558 non-null    int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 43.6+ KB

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'])

# Incorporate the other graph properties
plt.title('City Latitude versus Max Temperature')
plt.ylabel('Max Temperature (Celcius)')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'])

# Incorporate the other graph properties
plt.title('City Latitude versus Humidity')
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'])

# Incorporate the other graph properties
plt.title('City Latitude versus Cloudiness')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'])

# Incorporate the other graph properties
plt.title('City Latitude versus Wind Speed')
plt.ylabel('Cloudiness (m/s)')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regressfunction (hemi_param, weather_param):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(hemi_param, weather_param)
    line_plot = hemi_param * slope + intercept
    line_annotate = f"y = {round(slope,2)}x + {round(intercept,2)}"
    r_value = f"The r-value is: {round(rvalue,2)}"
    return line_plot, line_annotate, r_value

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           bilibino  68.0546  166.4372     16.49        37           8
# 1             albany  42.6001  -73.9662     18.21        68          89
# 3        olonkinbyen  70.9221   -8.7187      2.34        97         100
# 5           arnprior  45.4334  -76.3494     16.99        73         100
# 8           hamilton  39.1834  -84.5333     25.49        27           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.07      RU  1686261475
# 1              1.99      US  1686261442
# 3              8.51      SJ  1686261475
# 5              1.83      CA  1686261475
# 8              4.63      US  1686260898

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2             port lincoln -34.7333  135.8667     13.67        57         100
# 4             invercargill -46.4000  168.3500      2.51        89           8
# 6                geraldton -28.7667  114.6000      8.23        93           0
# 7           puerto natales -51.7236  -72.4875      0.35        86           8
# 10       port-aux-francais -49.3500   70.2167      5.10        76          75
#
#          Wind Speed Country        Date
# City_ID
# 2              6.23      AU  1686261475
# 4              1.57      NZ  1686261042
# 6              4.12      AU  1686261312
# 7              2.00      CL  1686261474
# 10             8.44      TF  1686261463

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
plt.plot(northern_hemi_df['Lat'], regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])[0], color='r')
plt.annotate(regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])[1],(50,35),fontsize=12,color='r')
plt.title('City Latitude versus Max Temperature (Northern Hemisphere)')
plt.ylabel('Max Temperature (Celcius)')
plt.xlabel('Latitude')
print(regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])[2])
plt.show()
# Out:
# The r-value is: -0.76

# %%
# Linear regression on Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
plt.plot(southern_hemi_df['Lat'], regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])[0], color='r')
plt.annotate(regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])[1],(-55, 26),fontsize=12,color='r')
plt.title('City Latitude versus Max Temperature (Southern Hemisphere)')
plt.ylabel('Max Temperature (Celcius)')
plt.xlabel('Latitude')
print(regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])[2])
plt.show()
# Out:
# The r-value is: 0.84

# %% [markdown]
# **Discussion about the linear relationship:** With r-values approaching -1 (in the Northern Hemisphere) and -1 (in the Southern Hemisphere), the correlation between latitude and max temperature is quite strong. As a subject city is further from the equator (0 latitude), it's maximum temperature can be predicted to be lower.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
plt.plot(northern_hemi_df['Lat'], regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])[0], color='r')
plt.annotate(regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])[1],(52, 19),fontsize=12,color='r')
plt.title('City Latitude versus Humidity (Northern Hemisphere)')
plt.ylabel('Max Temperature (Celcius)')
plt.xlabel('Latitude')
print(regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])[2])
plt.show()
# Out:
# The r-value is: -0.05

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
plt.plot(southern_hemi_df['Lat'], regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])[0], color='r')
plt.annotate(regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])[1],(-56, 43),fontsize=12,color='r')
plt.title('City Latitude versus Humidity (Southern Hemisphere)')
plt.ylabel('Max Temperature (Celcius)')
plt.xlabel('Latitude')
print(regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])[2])
plt.show()
# Out:
# The r-value is: 0.08

# %% [markdown]
# **Discussion about the linear relationship:** The correlation between latitude and humidity is negligible. There is a slight negative and slight positive r-value for the two hemispheres, but not enough to make confident conclusions about humidity when given a latitude value.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
plt.plot(northern_hemi_df['Lat'], regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])[0], color='r')
plt.annotate(regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])[1],(53, 30),fontsize=12,color='r')
plt.title('City Latitude versus Cloudiness (Northern Hemisphere)')
plt.ylabel('Max Temperature (Celcius)')
plt.xlabel('Latitude')
print(regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])[2])
plt.show()
# Out:
# The r-value is: -0.07

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
plt.plot(southern_hemi_df['Lat'], regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])[0], color='r')
plt.annotate(regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])[1],(-54, 27),fontsize=12,color='r')
plt.title('City Latitude versus Cloudiness (Southern Hemisphere)')
plt.ylabel('Max Temperature (Celcius)')
plt.xlabel('Latitude')
print(regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])[2])
plt.show()
# Out:
# The r-value is: 0.1

# %% [markdown]
# **Discussion about the linear relationship:** Whle the correlation is weak in both the Northern Hemisphere and the Southern Hemisphere, it is slightly less weak in the Southern Hemisphere, where cloudiness does appear to increase as you get further from the equator.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
plt.plot(northern_hemi_df['Lat'], regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])[0], color='r')
plt.annotate(regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])[1],(35, 10),fontsize=12,color='r')
plt.title('City Latitude versus Wind Speed (Northern Hemisphere)')
plt.ylabel('Max Temperature (Celcius)')
plt.xlabel('Latitude')
print(regressfunction(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])[2])
plt.show()
# Out:
# The r-value is: -0.09

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
plt.plot(southern_hemi_df['Lat'], regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])[0], color='r')
plt.annotate(regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])[1],(-27, 9),fontsize=12,color='r')
plt.title('City Latitude versus Wind Speed (Southern Hemisphere)')
plt.ylabel('Max Temperature (Celcius)')
plt.xlabel('Latitude')
print(regressfunction(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])[2])
plt.show()
# Out:
# The r-value is: -0.24

# %% [markdown]
# **Discussion about the linear relationship:** Similar to cloudiness, the correlations are both weak, but the Southern Hemisphere does show a suggestion that wind speed will be stronger as you get further from the equator.
